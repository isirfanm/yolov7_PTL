# %% [markdown]
# # Pruning

# %% [markdown]
# ## Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Binus/MTI/DL/PTL_component/yolov7_PTL
# Out:
# /content/drive/MyDrive/Binus/MTI/DL/PTL_component/yolov7_PTL

# %% [markdown]
# # Install Library

# %% [markdown]
# ## Requirements

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 128.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !pip install "tensorboard==2.4.1"
# !pip install "tensorboard>2.4"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 71.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.0.2
#     Uninstalling tensorboard-2.0.2:
#       Successfully uninstalled tensorboard-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.19.0 requires tensorboard~=2.19.0, but you have tensorboard 2.20.0 which is incompatible.
# ...

# %%
# !pip install "torchvision<0.20"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 64.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.0/797.0 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 109.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 79.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 56.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 5.7 MB/s eta 0:00:00
# ...

# %%
# !pip install "numpy==1.26.4"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 97.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# !pip install "thop==0.1.1.post2209072238"

# %%
# !pip install "protobuf<3.21"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 7.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.6
#     Uninstalling protobuf-5.29.6:
#       Successfully uninstalled protobuf-5.29.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-logging 3.13.0 requires google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1, but you have google-auth 1.35.0 which is incompatible.
# tensorflow-metadata 1.17.3 requires protobuf>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# google-ai-generativelanguage 0.6.15 requires google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1, but you have google-auth 1.35.0 which is incompatible.
# google-cloud-bigtable 2.35.0 requires google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.23.0, but you have google-auth 1.35.0 which is incompatible.
# ...

# %%
# !pip freeze > requirements_freeze.txt

# %% [markdown]
# ## Testing

# %%
# !python test_prune.py --data "data/furnas.yaml" --img-size 640 --batch-size 32 --conf-thres 0.001 --iou-thres 0.65 --device 0 --weights "runs/train/yolov7-tiny-ptl-gridsearch_0_/weights/best.pt" --name yolov7-tiny_prune_valx
# Out:
# Namespace(weights=['runs/train/yolov7-tiny-ptl-gridsearch_0_/weights/best.pt'], data='data/furnas.yaml', batch_size=32, img_size=640, conf_thres=0.001, iou_thres=0.65, task='val', device='0', single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test', name='yolov7-tiny_prune_valx', exist_ok=False, no_trace=False, v5_metric=False, modification='', prune_output='output.txt', pruning_params='', criterion=0, pruning_rate='0.5')
# YOLOR 🚀 ece3387 torch 2.4.1+cu121 CUDA:0 (Tesla T4, 14912.6875MB)
#
# ...

# %% [markdown]
# ## Sensitivity Analysis

# %%
# !python test_prune.py --data "data/furnas.yaml" --img-size 640 --batch-size 32 --conf-thres 0.001 --iou-thres 0.65 --device 0 --weights "runs/train/yolov7-tiny-ptl-gridsearch_0_/weights/best.pt" --task pruning_sensitivity_analysis --name yolov7-tiny_prune_sensitivityx --modification prune-structured --prune-output outputx.txt --pruning-rate '[0.0]'
# Out:
# Namespace(weights=['runs/train/yolov7-tiny-ptl-gridsearch_0_/weights/best.pt'], data='data/furnas.yaml', batch_size=32, img_size=640, conf_thres=0.001, iou_thres=0.65, task='pruning_sensitivity_analysis', device='0', single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test', name='yolov7-tiny_prune_sensitivityx', exist_ok=False, no_trace=False, v5_metric=False, modification='prune-structured', prune_output='outputx.txt', pruning_params='', criterion=0, pruning_rate='[0.0]')
# YOLOR 🚀 ece3387 torch 2.4.1+cu121 CUDA:0 (Tesla T4, 14912.6875MB)
#
# ...

# %% [markdown]
# ## Selecting layers and pruning rates

# %%
# !python layer_selection.py --output "output/yolov7-tiny-ptl-gridsearch_0_" --params 6033616 --flops 13.1 --params-layers 6 --flops-layers 5 --params-map 20 --flops-map 20
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Binus/MTI/DL/PTL_component/yolov7_PTL/layer_selection.py", line 212, in <module>
#   File "/content/drive/MyDrive/Binus/MTI/DL/PTL_component/yolov7_PTL/layer_selection.py", line 67, in select
#     number_params = [max_val.index(val) for val in max_val if val > max_p / frac]
#                                                               ^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ^C

# %% [markdown]
# Layers and pruning rates in [(0, 0.5), (15, 0.75), (19, 0.5), (45, 0.5), (53, 0.5), (18, 0.5), (20, 0.75), (51, 0.25)]
# are selected for values in ['FLOPS', 'FLOPS', 'both', 'both', 'FLOPS', 'params', 'params', 'params'] respectively

# %% [markdown]
# ## Testing with the pruning parameters

# %%
# !python test_prune.py --data "data/furnas.yaml" --img-size 640 --batch-size 32 --conf-thres 0.001 --iou-thres 0.65  --device 0 --weights "runs/train/yolov7-tiny-ptl-gridsearch_0_/weights/best.pt" --name yolov7-tiny-prune-25-valx --modification prune-structured --pruning-params '[(0, 0.5), (15, 0.75), (19, 0.5), (45, 0.5), (53, 0.5), (18, 0.5), (20, 0.75), (51, 0.25)]'
# Out:
# Namespace(weights=['runs/train/yolov7-tiny-ptl-gridsearch_0_/weights/best.pt'], data='data/furnas.yaml', batch_size=32, img_size=640, conf_thres=0.001, iou_thres=0.65, task='val', device='0', single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test', name='yolov7-tiny-prune-25-val', exist_ok=False, no_trace=False, v5_metric=False, modification='prune-structured', prune_output='output.txt', pruning_params='[(0, 0.5), (15, 0.75), (19, 0.5), (45, 0.5), (53, 0.5), (18, 0.5), (20, 0.75), (51, 0.25)]', criterion=0, pruning_rate='0.5')
# YOLOR 🚀 c6199e1 torch 2.4.1+cu121 CUDA:0 (Tesla T4, 14912.6875MB)
#
# ...

# %% [markdown]
# ## Fine-tuning with the pruning parameters

# %%
# !python train_prune.py --device 0 --batch-size 32 --data "data/furnas.yaml" --img-size 640 --weights "runs/train/yolov7-tiny-ptl-gridsearch_0_/weights/best.pt" --name yolov7-tiny-prune-25-fine-tunedx --hyp "data/hyp.scratch.tiny.custom.yaml" --pruning-params "[(0, 0.0), (15, 0.0), (19, 0.0), (45, 0.0), (53, 0.0), (18, 0.0), (20, 0.0), (51, 0.0)]" --criterion 0 --cache-images --epochs 10
# Out:
# 2026-03-19 06:49:33.869129: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773902973.889386   17610 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773902973.895598   17610 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773902973.911629   17610 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ## Evaluation

# %%
# !python test.py --data "data/furnas.yaml" --img-size 640 --batch-size 1 --conf-thres 0.001 --iou-thres 0.65 --device '0' --weights "runs/train/yolov7-tiny-prune-25-fine-tunedx2/weights/best.pt" --name yolov7-tiny-prunex --task test --verbose
# Out:
# Namespace(weights=['runs/train/yolov7-tiny-prune-25-fine-tunedx2/weights/best.pt'], data='data/furnas.yaml', batch_size=1, img_size=640, conf_thres=0.001, iou_thres=0.65, task='test', device='0', single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test', name='yolov7-tiny-prunex', exist_ok=False, no_trace=False, v5_metric=False)
# YOLOR 🚀 ece3387 torch 2.4.1+cu121 CUDA:0 (Tesla T4, 14912.6875MB)
#
# ...

# %%
# !python test.py --data "data/furnas.yaml" --img-size 640 --batch-size 1 --conf-thres 0.001 --iou-thres 0.65 --device '0' --weights "runs/train/yolov7-tiny-ptl-gridsearch_0_/weights/best.pt" --name yolov7-tiny-prunex --task test --verbose
# Out:
# Namespace(weights=['runs/train/yolov7-tiny-ptl-gridsearch_0_/weights/best.pt'], data='data/furnas.yaml', batch_size=1, img_size=640, conf_thres=0.001, iou_thres=0.65, task='test', device='0', single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test', name='yolov7-tiny-prunex', exist_ok=False, no_trace=False, v5_metric=False)
# YOLOR 🚀 ece3387 torch 2.4.1+cu121 CUDA:0 (Tesla T4, 14912.6875MB)
#
# ...
