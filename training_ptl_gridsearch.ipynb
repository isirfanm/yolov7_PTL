# %% [markdown]
# # Preparation

# %% [markdown]
# ## Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Clone Repository

# %%
# %cd /content/drive/MyDrive/Binus/MTI/DL/PTL_component
# Out:
# /content/drive/MyDrive/Binus/MTI/DL/PTL_component

# %%
# !git clone https://github.com/isirfanm/yolov7_PTL.git
# Out:
# Cloning into 'yolov7_PTL'...
# remote: Enumerating objects: 670, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 670 (delta 24), reused 41 (delta 16), pack-reused 619 (from 1)
# Receiving objects: 100% (670/670), 43.02 MiB | 23.81 MiB/s, done.
# Resolving deltas: 100% (319/319), done.

# %%
# %cd /content/drive/MyDrive/Binus/MTI/DL/PTL_component/yolov7_PTL
# Out:
# /content/drive/MyDrive/Binus/MTI/DL/PTL_component/yolov7_PTL

# %%
# !git checkout ptl
# Out:
# Branch 'ptl' set up to track remote branch 'ptl' from 'origin'.
# Switched to a new branch 'ptl'

# %%
# !git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 4), reused 5 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 425 bytes | 3.00 KiB/s, done.
# From https://github.com/isirfanm/yolov7_PTL
#    7ee64ce..3a7edaa  ptl        -> origin/ptl
# Updating 7ee64ce..3a7edaa
# Fast-forward
#  train.py          | 4 ++--
#  utils/datasets.py | 2 +-
#  2 files changed, 3 insertions(+), 3 deletions(-)

# %% [markdown]
# # Copy Dataset

# %%
# %cd /content
# Out:
# /content

# %%
# %cp -r /content/drive/MyDrive/Binus/MTI/DL/PTL_component/furnas_dataset_v0.07 .

# %%
# !ls
# Out:
# cfg	detect.py  hubconf.py  models	  requirements.txt  tools	  utils
# data	export.py  inference   paper	  scripts	    train_aux.py
# deploy	figure	   LICENSE.md  README.md  test.py	    train.py

# %% [markdown]
# # Install Library

# %% [markdown]
# ## Requirements

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached numpy-1.23.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# ...
# Using cached numpy-1.23.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.19.6 which is incompatible.
# scikit-image 0.25.2 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# blosc2 3.6.1 requires numpy>=1.26, but you have numpy 1.23.5 which is incompatible.
# albucore 0.0.24 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# ...

# %%
# !pip install "tensorboard==2.4.1"

# %%
# !pip install "torchvision<0.20"

# %%
# !pip install "numpy==1.26.4"

# %%
# !pip freeze > requirements_freeze.txt

# %% [markdown]
# # Train Model

# %% [markdown]
# ## Go to working directory

# %%
# %cd /content/drive/MyDrive/Binus/MTI/DL/PTL_component/yolov7_PTL
# Out:
# /content/drive/MyDrive/Binus/MTI/DL/PTL_component/yolov7_PTL

# %%
# %cd yolov7_PTL
# Out:
# /content/yolov7_PTL

# %% [markdown]
# ## Training

# %% [markdown]
# ### Prepare

# %%
# prompt: train yolov7-tiny model with grid search and early stop
import yaml
import wandb
import subprocess
import json

# Define your dataset configuration file path
data_yaml_path = 'data/furnas.yaml' # Make sure this path is correct and the file exists

# Define the base configuration for yolov7-tiny
config_file = 'cfg/training/yolov7-tiny-custom.yaml' # Adjust path if necessary

# Define the hyperparameter
hyperparameter_file1 = 'data/hyp.scratch.tiny.custom1.yaml' # init LR 0.01
hyperparameter_file2 = 'data/hyp.scratch.tiny.custom2.yaml' # init LR 0.001

# %%
import wandb
wandb.login()

# 60ba0d6f5c829cfe4a7ec5495357a70f06dc86df
# Out:
# True

# %% [markdown]
# ### Single Train (Scratch)

# %%
# !python train.py --device '0' --workers 64 --batch-size 64 --epochs 300  --data "data/furnas.yaml" --cfg "yolov7-tiny-custom.yaml"  --name yolov7-custom --hyp "data/hyp.scratch.tiny.custom.yaml" --weights '' --adam --cache-images
# Out:
# 2025-07-03 15:26:59.282008: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-03 15:26:59.299108: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751556419.320746    8572 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751556419.327345    8572 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ### Single Train

# %%
# !python train.py --device '0' --workers 64 --batch-size 64 --epochs 300  --data "data/furnas.yaml" --cfg "yolov7-tiny-custom.yaml"  --name yolov7-tiny-ptl --hyp "data/hyp.scratch.tiny.custom.yaml" --weights './yolov7-tiny.pt' --adam
# Out:
# 2025-08-02 21:16:38.410516: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-02 21:16:38.428315: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754169398.449386    5552 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754169398.455791    5552 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
cmd_parts = ['python', 'train.py', '--img-size', '640', '--batch-size', '16', '--epochs', '300', '--data', 'data/furnas.yaml', '--cfg', 'cfg/training/yolov7-tiny-custom.yaml', '--weights', './yolov7-tiny.pt', '--hyp', 'data/hyp.scratch.tiny.custom1.yaml', '--name', 'yolov7-tiny-ptl-gridsearch_0', '--cache-images', '--early-stop-patience', '20', '--device', '0']

# %%
import subprocess

process = subprocess.run(cmd_parts)

if process.returncode != 0:
    print(f"Training failed with return code {process.returncode}")
else:
    print("Training completed successfully.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-255015799.py in <cell line: 0>()
#       1 import subprocess
#       2
# ----> 3 process = subprocess.run(cmd_parts)
#       4
#       5 if process.returncode != 0:
#
# /usr/lib/python3.11/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548     with Popen(*popenargs, **kwargs) as process:
#     549         try:
# --> 550             stdout, stderr = process.communicate(input, timeout=timeout)
#     551         except TimeoutExpired as exc:
#     552             process.kill()
#
# /usr/lib/python3.11/subprocess.py in communicate(self, input, timeout)
#    1199                 stderr = self.stderr.read()
#    1200                 self.stderr.close()
# -> 1201             self.wait()
#    1202         else:
#    1203             if timeout is not None:
#
# ...

# %%
 cmd_string = " ".join(cmd_parts)

# %%
cmd_string
# Out:
# 'python train.py --img-size 640 --batch-size 16 --epochs 300 --data data/furnas.yaml --cfg cfg/training/yolov7-tiny-custom.yaml --weights ./yolov7-tiny.pt --hyp data/hyp.scratch.tiny.custom1.yaml --name yolov7-tiny-ptl-gridsearch_0 --cache-images --early-stop-patience 20 --device 0'

# %%
# !python train.py --img-size 640 --batch-size 16 --epochs 300 --data data/furnas.yaml --cfg cfg/training/yolov7-tiny-custom.yaml --weights ./yolov7-tiny.pt --hyp data/hyp.scratch.tiny.custom1.yaml --name yolov7-tiny-ptl-gridsearch_0 --cache-images --early-stop-patience 20 --device 0
# Out:
# 2025-08-02 21:28:06.764236: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-02 21:28:06.781847: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754170086.803347   10772 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754170086.809987   10772 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ### Training with Grid Search

# %%
# Define the grid search parameters
# Example grid search: varying batch size and learning rate
grid_params = {
    'batch_size': [16, 32, 64],
    'epochs': [300], # Keep epochs relatively low for grid search iterations
    'img_size': [640],
    'cfg': [config_file],
    'data': [data_yaml_path],
    'weights': ['./yolov7-tiny.pt'], # Start training from scratch or a pretrained tiny model
    'hyp': [hyperparameter_file1, hyperparameter_file2], # initial lr 0.01 & 0.001
    'name': ['yolov7-tiny-ptl-gridsearch'],
    'opt-alg': ['sgd', 'adam'],
    'early-stop-patience': [20] # Early stopping patience
}

# %%
import datetime

# Function to train a single model configuration
def train_model(params):
    print("\n" + "="*50)
    print("Starting training with parameters:")
    print(json.dumps(params, indent=2))
    print("="*50 + "\n")

    # Construct the training command
    command = [
        'python', 'train.py',
        '--img-size', str(params['img_size']),
        '--batch-size', str(params['batch_size']),
        '--epochs', str(params['epochs']),
        '--data', params['data'],
        '--cfg', params['cfg'],
        '--weights', params['weights'],
        '--hyp', params['hyp'],
        '--name', params['name'],
        '--cache-images',
        '--early-stop-patience', str(params['early-stop-patience'])
    ]

    # Add --device if you want to specify GPU or CPU
    command.extend(['--device', '0']) # Use GPU 0
    # command.extend(['--device', 'cpu']) # Use CPU

    # Add --bbox_interval and --image_weights if using wandb and logging specific things
    # command.extend(['--bbox_interval', '1', '--image_weights'])

    # Optimization Alg
    if params['opt-alg'] == 'adam':
        command.extend(['--adam'])

    # resume training
    if params.get('resume', False):
        command.extend(['--resume'])

    print(f"Running: {command}")
    process = subprocess.run(command)

    if process.returncode != 0:
        print(f"[{datetime.datetime.now()}] Training failed with return code {process.returncode}")
        raise Exception(f"Training failed with return code {process.returncode}")
    else:
        print(f"[{datetime.datetime.now()}] Training completed successfully.")

    # try:
    #     # Execute the training command
    #     process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    #     stdout, stderr = process.communicate()

    #     print("STDOUT:")
    #     print(stdout.decode('utf-8'))
    #     print("STDERR:")
    #     print(stderr.decode('utf-8'))

    #     if process.returncode != 0:
    #         print(f"Training failed with return code {process.returncode}")
    #     else:
    #         print("Training completed successfully.")

    # except Exception as e:
    #     print(f"An error occurred during training: {e}")

# %%
# Simple grid search implementation
# This is a basic implementation. For more complex grid searches,
# consider libraries like sklearn.model_selection.ParameterGrid
# or tools integrated with experiment trackers like Wandb Sweeps.
from itertools import product

# Generate combinations of parameters
param_combinations = list(product(
    grid_params['batch_size'],
    grid_params['epochs'],
    grid_params['img_size'],
    grid_params['cfg'],
    grid_params['data'],
    grid_params['weights'],
    grid_params['hyp'],
    grid_params['name'],
    grid_params['opt-alg'],
    grid_params['early-stop-patience']
))

print(f"Total grid search runs: {len(param_combinations)}")
# Out:
# Total grid search runs: 12

# %%
param_combinations
# Out:
# [(16,
#   300,
#   640,
#   'cfg/training/yolov7-tiny-custom.yaml',
#   'data/furnas.yaml',
#   './yolov7-tiny.pt',
#   'data/hyp.scratch.tiny.custom1.yaml',
#   'yolov7-tiny-ptl-gridsearch',
#   'sgd',
#   20),
#  (16,
#   300,
#   640,
#   'cfg/training/yolov7-tiny-custom.yaml',
#   'data/furnas.yaml',
#   './yolov7-tiny.pt',
#   'data/hyp.scratch.tiny.custom1.yaml',
#   'yolov7-tiny-ptl-gridsearch',
#   'adam',
#   20),
#  (16,
#   300,
#   640,
#   'cfg/training/yolov7-tiny-custom.yaml',
#   'data/furnas.yaml',
#   './yolov7-tiny.pt',
#   'data/hyp.scratch.tiny.custom2.yaml',
#   'yolov7-tiny-ptl-gridsearch',
#   'sgd',
#   20),
#  (16,
#   300,
#   640,
#   'cfg/training/yolov7-tiny-custom.yaml',
#   'data/furnas.yaml',
#   './yolov7-tiny.pt',
#   'data/hyp.scratch.tiny.custom2.yaml',
#   'yolov7-tiny-ptl-gridsearch',
#   'adam',
#   20),
#  (32,
#   300,
#   640,
#   'cfg/training/yolov7-tiny-custom.yaml',
#   'data/furnas.yaml',
#   './yolov7-tiny.pt',
# ...

# %%
param_combinations = [(16,
  300,
  640,
  'cfg/training/yolov7-tiny-custom.yaml',
  'data/furnas.yaml',
  './yolov7-tiny.pt',
  'data/hyp.scratch.tiny.custom1.yaml',
  'yolov7-tiny-ptl-gridsearch',
  'sgd',
  20),
 (16,
  300,
  640,
  'cfg/training/yolov7-tiny-custom.yaml',
  'data/furnas.yaml',
  './yolov7-tiny.pt',
  'data/hyp.scratch.tiny.custom1.yaml',
  'yolov7-tiny-ptl-gridsearch',
  'adam',
  20),
 (16,
  300,
  640,
  'cfg/training/yolov7-tiny-custom.yaml',
  'data/furnas.yaml',
  './yolov7-tiny.pt',
  'data/hyp.scratch.tiny.custom2.yaml',
  'yolov7-tiny-ptl-gridsearch',
  'sgd',
  20),
 (16,
  300,
  640,
  'cfg/training/yolov7-tiny-custom.yaml',
  'data/furnas.yaml',
  './yolov7-tiny.pt',
  'data/hyp.scratch.tiny.custom2.yaml',
  'yolov7-tiny-ptl-gridsearch',
  'adam',
  20),
 (32,
  300,
  640,
  'cfg/training/yolov7-tiny-custom.yaml',
  'data/furnas.yaml',
  './yolov7-tiny.pt',
  'data/hyp.scratch.tiny.custom1.yaml',
  'yolov7-tiny-ptl-gridsearch',
  'sgd',
  20),
 (32,
  300,
  640,
  'cfg/training/yolov7-tiny-custom.yaml',
  'data/furnas.yaml',
  './yolov7-tiny.pt',
  'data/hyp.scratch.tiny.custom1.yaml',
  'yolov7-tiny-ptl-gridsearch',
  'adam',
  20),
 (32,
  300,
  640,
  'cfg/training/yolov7-tiny-custom.yaml',
  'data/furnas.yaml',
  './yolov7-tiny.pt',
  'data/hyp.scratch.tiny.custom2.yaml',
  'yolov7-tiny-ptl-gridsearch',
  'sgd',
  20),
 (32,
  300,
  640,
  'cfg/training/yolov7-tiny-custom.yaml',
  'data/furnas.yaml',
  './yolov7-tiny.pt',
  'data/hyp.scratch.tiny.custom2.yaml',
  'yolov7-tiny-ptl-gridsearch',
  'adam',
  20),
 (64,
  300,
  640,
  'cfg/training/yolov7-tiny-custom.yaml',
  'data/furnas.yaml',
  './yolov7-tiny.pt',
  'data/hyp.scratch.tiny.custom1.yaml',
  'yolov7-tiny-ptl-gridsearch',
  'sgd',
  20),
 (64,
  300,
  640,
  'cfg/training/yolov7-tiny-custom.yaml',
  'data/furnas.yaml',
  './yolov7-tiny.pt',
  'data/hyp.scratch.tiny.custom1.yaml',
  'yolov7-tiny-ptl-gridsearch',
  'adam',
  20),
 (64,
  300,
  640,
  'cfg/training/yolov7-tiny-custom.yaml',
  'data/furnas.yaml',
  './yolov7-tiny.pt',
  'data/hyp.scratch.tiny.custom2.yaml',
  'yolov7-tiny-ptl-gridsearch',
  'sgd',
  20),
 (64,
  300,
  640,
  'cfg/training/yolov7-tiny-custom.yaml',
  'data/furnas.yaml',
  './yolov7-tiny.pt',
  'data/hyp.scratch.tiny.custom2.yaml',
  'yolov7-tiny-ptl-gridsearch',
  'adam',
  20)]

# %%
print(param_combinations)
# Out:
# [(16, 300, 640, 'cfg/training/yolov7-tiny-custom.yaml', 'data/furnas.yaml', './yolov7-tiny.pt', 'data/hyp.scratch.tiny.custom1.yaml', 'yolov7-tiny-ptl-gridsearch', 'sgd', 20), (16, 300, 640, 'cfg/training/yolov7-tiny-custom.yaml', 'data/furnas.yaml', './yolov7-tiny.pt', 'data/hyp.scratch.tiny.custom1.yaml', 'yolov7-tiny-ptl-gridsearch', 'adam', 20), (16, 300, 640, 'cfg/training/yolov7-tiny-custom.yaml', 'data/furnas.yaml', './yolov7-tiny.pt', 'data/hyp.scratch.tiny.custom2.yaml', 'yolov7-tiny-ptl-gridsearch', 'sgd', 20), (16, 300, 640, 'cfg/training/yolov7-tiny-custom.yaml', 'data/furnas.yaml', './yolov7-tiny.pt', 'data/hyp.scratch.tiny.custom2.yaml', 'yolov7-tiny-ptl-gridsearch', 'adam', 20), (32, 300, 640, 'cfg/training/yolov7-tiny-custom.yaml', 'data/furnas.yaml', './yolov7-tiny.pt', 'data/hyp.scratch.tiny.custom1.yaml', 'yolov7-tiny-ptl-gridsearch', 'sgd', 20), (32, 300, 640, 'cfg/training/yolov7-tiny-custom.yaml', 'data/furnas.yaml', './yolov7-tiny.pt', 'data/hyp.scratch.tiny.cu
# ...

# %%
import datetime

def run_grid_search(param_combinations, continue_from_idx=-1, resume=False):
  # Run 1 training for each combination
  for i, combo in enumerate(param_combinations):

      # skip combo
      if i < continue_from_idx:
          continue

      model_name = f"{combo[7]}_{i}_" # Append index to name for unique runs
      print(f"[{datetime.datetime.now()}] Trainning start: {model_name}")
      params = {
          'batch_size': combo[0],
          'epochs': combo[1],
          'img_size': combo[2],
          'cfg': combo[3],
          'data': combo[4],
          'weights': combo[5],
          'hyp': combo[6],
          'name': model_name,
          'opt-alg': combo[8],
          'early-stop-patience': combo[9]
      }

      # resume intrupted training
      if i == continue_from_idx:
        params['resume'] = resume

      train_model(params)
      print(f"[{datetime.datetime.now()}] Trainning finished: {model_name}")

  print("\n" + "="*50)
  print(f"[{datetime.datetime.now()}] Grid search completed.")
  print("="*50)

# %%
# run training with gridsearch
run_grid_search(param_combinations)
# Out:
# Trainning start: yolov7-tiny-ptl-gridsearch_0_
#
# ...
# Starting training with parameters:
# {
#   "batch_size": 16,
#   "epochs": 300,
#   "img_size": 640,
#   "cfg": "cfg/training/yolov7-tiny-custom.yaml",
#   "data": "data/furnas.yaml",
#   "weights": "./yolov7-tiny.pt",
#   "hyp": "data/hyp.scratch.tiny.custom1.yaml",
#   "name": "yolov7-tiny-ptl-gridsearch_0_",
#   "opt-alg": "sgd",
#   "early-stop-patience": 20
# }
# ...
#
# Running: ['python', 'train.py', '--img-size', '640', '--batch-size', '16', '--epochs', '300', '--data', 'data/furnas.yaml', '--cfg', 'cfg/training/yolov7-tiny-custom.yaml', '--weights', './yolov7-tiny.pt', '--hyp', 'data/hyp.scratch.tiny.custom1.yaml', '--name', 'yolov7-tiny-ptl-gridsearch_0_', '--cache-images', '--early-stop-patience', '20', '--device', '0']
# Training completed successfully.
# Trainning finished: yolov7-tiny-ptl-gridsearch_0_
# Trainning start: yolov7-tiny-ptl-gridsearch_1_
#
# ...
# Starting training with parameters:
# {
#   "batch_size": 16,
# ...

# %%
# run training with gridsearch
run_grid_search(param_combinations, continue_from_idx=2, resume=False)
# Out:
# [2025-08-03 15:02:17.843996] Trainning start: yolov7-tiny-ptl-gridsearch_2_
#
# ...
# Starting training with parameters:
# {
#   "batch_size": 16,
#   "epochs": 300,
#   "img_size": 640,
#   "cfg": "cfg/training/yolov7-tiny-custom.yaml",
#   "data": "data/furnas.yaml",
#   "weights": "./yolov7-tiny.pt",
#   "hyp": "data/hyp.scratch.tiny.custom2.yaml",
#   "name": "yolov7-tiny-ptl-gridsearch_2_",
#   "opt-alg": "sgd",
#   "early-stop-patience": 20,
#   "resume": false
# }
# ...
#
# Running: ['python', 'train.py', '--img-size', '640', '--batch-size', '16', '--epochs', '300', '--data', 'data/furnas.yaml', '--cfg', 'cfg/training/yolov7-tiny-custom.yaml', '--weights', './yolov7-tiny.pt', '--hyp', 'data/hyp.scratch.tiny.custom2.yaml', '--name', 'yolov7-tiny-ptl-gridsearch_2_', '--cache-images', '--early-stop-patience', '20', '--device', '0']
# Training completed successfully.
# [2025-08-03 17:04:06.941580] Trainning finished: yolov7-tiny-ptl-gridsearch_2_
# ...

# %%
# run training with gridsearch
run_grid_search(param_combinations, continue_from_idx=8, resume=False)
# Out:
# [2025-08-05 08:46:37.155948] Trainning start: yolov7-tiny-ptl-gridsearch_8_
#
# ...
# Starting training with parameters:
# {
#   "batch_size": 64,
#   "epochs": 300,
#   "img_size": 640,
#   "cfg": "cfg/training/yolov7-tiny-custom.yaml",
#   "data": "data/furnas.yaml",
#   "weights": "./yolov7-tiny.pt",
#   "hyp": "data/hyp.scratch.tiny.custom1.yaml",
#   "name": "yolov7-tiny-ptl-gridsearch_8_",
#   "opt-alg": "sgd",
#   "early-stop-patience": 20,
#   "resume": false
# }
# ...
#
# Running: ['python', 'train.py', '--img-size', '640', '--batch-size', '64', '--epochs', '300', '--data', 'data/furnas.yaml', '--cfg', 'cfg/training/yolov7-tiny-custom.yaml', '--weights', './yolov7-tiny.pt', '--hyp', 'data/hyp.scratch.tiny.custom1.yaml', '--name', 'yolov7-tiny-ptl-gridsearch_8_', '--cache-images', '--early-stop-patience', '20', '--device', '0']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...

# %%
# run training with gridsearch
run_grid_search(param_combinations, continue_from_idx=8, resume=True)
# Out:
# [2025-08-05 10:15:29.672266] Trainning start: yolov7-tiny-ptl-gridsearch_8_
#
# ...
# Starting training with parameters:
# {
#   "batch_size": 64,
#   "epochs": 300,
#   "img_size": 640,
#   "cfg": "cfg/training/yolov7-tiny-custom.yaml",
#   "data": "data/furnas.yaml",
#   "weights": "./yolov7-tiny.pt",
#   "hyp": "data/hyp.scratch.tiny.custom1.yaml",
#   "name": "yolov7-tiny-ptl-gridsearch_8_",
#   "opt-alg": "sgd",
#   "early-stop-patience": 20,
#   "resume": true
# }
# ...
#
# Running: ['python', 'train.py', '--img-size', '640', '--batch-size', '64', '--epochs', '300', '--data', 'data/furnas.yaml', '--cfg', 'cfg/training/yolov7-tiny-custom.yaml', '--weights', './yolov7-tiny.pt', '--hyp', 'data/hyp.scratch.tiny.custom1.yaml', '--name', 'yolov7-tiny-ptl-gridsearch_8_', '--cache-images', '--early-stop-patience', '20', '--device', '0', '--resume']
# [2025-08-05 11:24:46.227201] Training completed successfully.
# [2025-08-05 11:24:46.227345] Trainning finished: yolov7-tiny-ptl-gridsearch_8_
# ...

# %%
# run training with gridsearch
run_grid_search(param_combinations, continue_from_idx=9, resume=False)
# Out:
# [2025-08-05 11:28:06.025791] Trainning start: yolov7-tiny-ptl-gridsearch_9_
#
# ...
# Starting training with parameters:
# {
#   "batch_size": 64,
#   "epochs": 300,
#   "img_size": 640,
#   "cfg": "cfg/training/yolov7-tiny-custom.yaml",
#   "data": "data/furnas.yaml",
#   "weights": "./yolov7-tiny.pt",
#   "hyp": "data/hyp.scratch.tiny.custom1.yaml",
#   "name": "yolov7-tiny-ptl-gridsearch_9_",
#   "opt-alg": "adam",
#   "early-stop-patience": 20,
#   "resume": false
# }
# ...
#
# Running: ['python', 'train.py', '--img-size', '640', '--batch-size', '64', '--epochs', '300', '--data', 'data/furnas.yaml', '--cfg', 'cfg/training/yolov7-tiny-custom.yaml', '--weights', './yolov7-tiny.pt', '--hyp', 'data/hyp.scratch.tiny.custom1.yaml', '--name', 'yolov7-tiny-ptl-gridsearch_9_', '--cache-images', '--early-stop-patience', '20', '--device', '0', '--adam']
# [2025-08-05 16:49:50.331472] Training completed successfully.
# [2025-08-05 16:49:50.331656] Trainning finished: yolov7-tiny-ptl-gridsearch_9_
# ...

# %%
# ' '.join(['python', 'train.py', '--img-size', '640', '--batch-size', '32', '--epochs', '300', '--data', 'data/furnas.yaml', '--cfg', 'cfg/training/yolov7-tiny-custom.yaml', '--weights', './yolov7-tiny.pt', '--hyp', 'data/hyp.scratch.tiny.custom2.yaml', '--name', 'yolov7-tiny-ptl-gridsearch_7_', '--cache-images', '--early-stop-patience', '20', '--device', '0', '--adam', '--resume'])
# Out:
# 'python train.py --img-size 640 --batch-size 32 --epochs 300 --data data/furnas.yaml --cfg cfg/training/yolov7-tiny-custom.yaml --weights ./yolov7-tiny.pt --hyp data/hyp.scratch.tiny.custom2.yaml --name yolov7-tiny-ptl-gridsearch_7_ --cache-images --early-stop-patience 20 --device 0 --adam --resume'

# %%
# !python train.py --img-size 640 --batch-size 32 --epochs 300 --data data/furnas.yaml --cfg cfg/training/yolov7-tiny-custom.yaml --weights ./yolov7-tiny.pt --hyp data/hyp.scratch.tiny.custom2.yaml --name yolov7-tiny-ptl-gridsearch_9_ --cache-images --early-stop-patience 20 --device 0 --adam --resume
# Out:
# 2025-08-05 11:25:52.957024: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-05 11:25:52.974553: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754393152.996229   48201 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754393153.002966   48201 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
import pandas as pd

# Load the grid search results
try:
    results_df = pd.read_csv('gridsearch_results.csv')
    display(results_df)

    # Find the row with the maximum mAP@.5
    best_run = results_df.loc[results_df['mAP50'].idxmax()]

    print("\n" + "="*50)
    print("Best performing run based on mAP@.5:")
    print(best_run)
    print("="*50)

except FileNotFoundError:
    print("Error: gridsearch_results.csv not found. Please ensure the file exists.")
except KeyError:
    print("Error: 'metrics/mAP_0.5' column not found in the CSV. Please check the column name.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#                                                weight  precision    recall  \
# 0   runs/train/yolov7-tiny-ptl-gridsearch_0_/weigh...   0.817685  0.870000
# 1   runs/train/yolov7-tiny-ptl-gridsearch_1_/weigh...   0.500000  0.664379
# 2   runs/train/yolov7-tiny-ptl-gridsearch_2_2/weig...   0.789251  0.806552
# 3   runs/train/yolov7-tiny-ptl-gridsearch_3_/weigh...   0.820555  0.799887
# 4   runs/train/yolov7-tiny-ptl-gridsearch_4_/weigh...   0.829638  0.857422
# 5   runs/train/yolov7-tiny-ptl-gridsearch_5_/weigh...   0.424800  0.476186
# 6   runs/train/yolov7-tiny-ptl-gridsearch_6_/weigh...   0.834325  0.806024
# 7   runs/train/yolov7-tiny-ptl-gridsearch_7_/weigh...   0.823040  0.839964
# 8   runs/train/yolov7-tiny-ptl-gridsearch_8_/weigh...   0.809208  0.814226
# 9   runs/train/yolov7-tiny-ptl-gridsearch_9_/weigh...   0.662171  0.674683
# 10  runs/train/yolov7-tiny-ptl-gridsearch_10_/weig...   0.815175  0.821011
# ...

# %%
best_run['weight']
# Out:
# 'runs/train/yolov7-tiny-ptl-gridsearch_0_/weights/best.pt'

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Go to working directory

# %%
# %cd /content/drive/MyDrive/Binus/MTI/DL/PTL_component/yolov7_PTL
# Out:
# /content/drive/MyDrive/Binus/MTI/DL/PTL_component/yolov7_PTL

# %% [markdown]
# ## Test model

# %% [markdown]
# ### Single Test (Scratch)

# %%
# !python test.py --data "data/furnas.yaml" --img-size 640 --batch-size 8 --conf-thres 0.001 --iou-thres 0.65 --device '0' --weights "runs/train/yolov7-custom2/weights/best.pt" --name yolov7-custom --task test --verbose
# Out:
# Namespace(weights=['runs/train/yolov7-custom2/weights/best.pt'], data='data/furnas.yaml', batch_size=8, img_size=640, conf_thres=0.001, iou_thres=0.65, task='test', device='0', single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test', name='yolov7-custom', exist_ok=False, no_trace=False, v5_metric=False)
# YOLOR 🚀 efbf587 torch 2.4.1+cu121 CUDA:0 (Tesla T4, 15095.0625MB)
#
# ...

# %% [markdown]
# ### Single Test

# %%
# !python test.py --data "data/furnas.yaml" --img-size 640 --batch-size 32 --conf-thres 0.001 --iou-thres 0.65 --device '0' --weights "./best.pt" --name yolov7-tiny-ptl --task test --verbose
# Out:
# Namespace(weights=['./best.pt'], data='data/furnas.yaml', batch_size=32, img_size=640, conf_thres=0.001, iou_thres=0.65, task='test', device='0', single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test', name='yolov7-tiny-ptl', exist_ok=False, no_trace=False, v5_metric=False)
# YOLOR 🚀 f86804c torch 2.4.1+cu121 CUDA:0 (Tesla T4, 15095.0625MB)
#
# ...

# %%
# prompt: evaluate model with test dataset

# After training is complete, evaluate the best model on the test set.

# Find the path to the best trained weights.
# This typically involves looking in the `runs/train` directory for the run
# with the best performance on the validation set (e.g., highest mAP@0.5).
# You'll need to identify the best run and the path to its 'best.pt' weights file.

# Example (you need to replace with the actual path):
# Assuming the best model from the grid search was run 0 and saved to runs/train/yolov7-tiny-grid-search_0/weights/best.pt
best_weights_path = '/content/drive/MyDrive/Binus/MTI/DL/PTL_component/furnas_dataset_v0.07/yolov7/runs/train/yolov7-tiny-grid-search_0/weights/best.pt' # **UPDATE THIS PATH**

# Define the path to the test dataset images and labels
test_data_yaml_path = '/content/drive/MyDrive/Binus/MTI/DL/PTL_component/furnas_dataset_v0.07/split_dataset/furnas_dataset.yaml' # Use the same data.yaml, it should point to train, val, and test paths

# Define the image size used during training
img_size_for_eval = 640 # Should match the img_size used for the best training run

# Define the confidence and IoU thresholds for evaluation
# These are common values, you might adjust them based on your requirements
conf_thres = 0.001  # Object confidence threshold (lower to detect more objects)
iou_thres = 0.65    # IoU threshold for NMS and evaluation metrics (higher for stricter matching)

print("\n" + "="*50)
print("Starting model evaluation on the test set...")
print(f"Using weights: {best_weights_path}")
print(f"Using data config: {test_data_yaml_path}")
print("="*50 + "\n")

# Construct the evaluation command (using detect.py or test.py if available)
# YOLOv7 typically uses `test.py` for evaluation on a dataset split.
# If you want to detect on individual images and visualize, use `detect.py`.
# We'll use `test.py` for standard evaluation metrics (mAP).

eval_command = [
    'python', 'test.py',
    '--img-size', str(img_size_for_eval),
    '--data', test_data_yaml_path,
    '--weights', best_weights_path,
    '--batch-size', '32', # Use a batch size that fits in memory
    '--conf-thres', str(conf_thres),
    '--iou-thres', str(iou_thres),
    '--task', 'test', # Specify that we are evaluating the 'test' split
    '--name', 'yolov7-tiny-test-eval' # Name for the evaluation run directory
]

# Add --device if you want to specify GPU or CPU
eval_command.extend(['--device', '0']) # Use GPU 0
# eval_command.extend(['--device', 'cpu']) # Use CPU

try:
    # Execute the evaluation command
    process = subprocess.Popen(eval_command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    stdout, stderr = process.communicate()

    print("STDOUT:")
    print(stdout.decode('utf-8'))
    print("STDERR:")
    print(stderr.decode('utf-8'))

    if process.returncode != 0:
        print(f"Evaluation failed with return code {process.returncode}")
    else:
        print("Evaluation completed successfully.")
        # The evaluation results (mAP, precision, recall, etc.) will be printed to stdout
        # and saved in the 'runs/test/yolov7-tiny-test-eval' directory.

except Exception as e:
    print(f"An error occurred during evaluation: {e}")

print("\n" + "="*50)
print("Evaluation completed.")
print("Check the output above and the 'runs/test' directory for results.")
print("="*50)

# Note: The path to the best weights (`best_weights_path`) is a placeholder.
# You need to manually identify the best training run from your grid search results
# (e.g., by checking the validation metrics printed during training or on Wandb)
# and update `best_weights_path` to point to the `weights/best.pt` file of that specific run.
# You might need to list the directories in `yolov7/runs/train` to find the correct path.

# %% [markdown]
# ### Gridsearch

# %%
# !python test.py --data "data/furnas.yaml" --img-size 640 --batch-size 1 --conf-thres 0.001 --iou-thres 0.65 --device '0' --weights "runs/train/yolov7-tiny-ptl-gridsearch_0_/weights/best.pt" --name yolov7-tiny-ptl-gridsearch --task test --verbose
# Out:
# Namespace(weights=['runs/train/yolov7-tiny-ptl-gridsearch_0_/weights/best.pt'], data='data/furnas.yaml', batch_size=1, img_size=640, conf_thres=0.001, iou_thres=0.65, task='test', device='0', single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test', name='yolov7-tiny-ptl-gridsearch', exist_ok=False, no_trace=False, v5_metric=False)
# YOLOR 🚀 f774c3a torch 2.6.0+cu124 CUDA:0 (Tesla T4, 15095.0625MB)
#
# Fusing layers...
# Model Summary: 200 layers, 6033616 parameters, 0 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.11/dist-packages/torch/functional.py:539: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...
