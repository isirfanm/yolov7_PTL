# %% [markdown]
# # Pruning

# %% [markdown]
# ## Testing

# %%
# !python test_prune.py --data "data/furnas.yaml" --img-size 640 --batch-size 32 --conf-thres 0.001 --iou-thres 0.65 --device "cpu" --weights yolov7-tiny.pt --name yolov7-tiny_prune_val
# Out:
# /home/irfan/.pyenv/versions/yolov7/lib/python3.9/site-packages/onnx/mapping.py:27: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   int(TensorProto.STRING): np.dtype(np.object)
# Traceback (most recent call last):
#   File "/home/irfan/workspace/home/Kuliah/tesis_PTL/Vitis-AI/yolov7_PTL/test_prune.py", line 15, in <module>
#     from models.experimental import attempt_load
#   File "/home/irfan/workspace/home/Kuliah/tesis_PTL/Vitis-AI/yolov7_PTL/models/experimental.py", line 6, in <module>
#     from models.common import Conv, DWConv
#   File "/home/irfan/workspace/home/Kuliah/tesis_PTL/Vitis-AI/yolov7_PTL/models/common.py", line 11, in <module>
#     from torchvision.ops import DeformConv2d
#   File "/home/irfan/.pyenv/versions/yolov7/lib/python3.9/site-packages/torchvision/__init__.py", line 10, in <module>
#     from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
# ...
